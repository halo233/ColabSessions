# %% [markdown]
# <a href="https://colab.research.google.com/github/halo233/ColabSessions/blob/Explore-Session/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %%
import os

# 1. Mount Drive (Make sure you did this first!)
from google.colab import drive
drive.mount('/content/drive')

# 2. Create a folder on your Drive for Unsloth settings
# !mkdir -p /content/drive/MyDrive/unsloth_data

# 3. Create a Symlink (The "Bridge")
# This tells the computer: "When you look for ~/.unsloth, actually go to my Drive."
# !ln -s /content/drive/MyDrive/unsloth_data ~/.unsloth
# Out:
# Mounted at /content/drive

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1307, done.
# remote: Counting objects: 100% (1307/1307), done.
# remote: Compressing objects: 100% (1123/1123), done.
# remote: Total 1307 (delta 187), reused 801 (delta 161), pack-reused 0 (from 0)
# Receiving objects: 100% (1307/1307), 33.49 MiB | 31.41 MiB/s, done.
# Resolving deltas: 100% (187/187), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  upgrading npm...
#   node           v20.19.0 | npm 11.14.1
#                  installing bun...
#                  bun installed (1.3.13)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/14  base packages         deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [===========---------]  8/14  flash-attn            warning        No compatible flash-attn prebuilt wheel found
#   deps           [====================] 14/14  ROCm torch (final)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: ggml-org/llama.cpp@b9093
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-05-10 01:14:01 [info     ] 🦥 Starting Unsloth Studio...
# 2026-05-10 01:14:01 [info     ]    Loading backend...
# 2026-05-10 01:14:01 [info     ]    Starting server...
# INFO:     Started server process [26846]
# INFO:     Waiting for application startup.
# Hardware detected: CPU (no GPU backend available)
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8888 (Press CTRL+C to quit)
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Studio UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-05-10T01:14:12.373741Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/gemma-4-E2B-it-GGUF/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-05-10T01:14:20.153123Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="https://8888-m-s-kkb-euw4b0-36aeephkr8r53-b.europe-west4-0.prod.colab.dev" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             If the link doesn't work, you can scroll down to view the UI generated directly in Colab.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             https://8888-m-...
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-05-10T01:14:26.391434Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 4011.57}
# {"timestamp": "2026-05-10T01:14:31.625908Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 7.92}
# {"timestamp": "2026-05-10T01:14:32.012599Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 165.38}
# {"timestamp": "2026-05-10T01:14:35.502590Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-05-10T01:14:36.400107Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 4189.67}
# {"timestamp": "2026-05-10T01:14:37.335524Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 38.75}
# {"timestamp": "2026-05-10T01:15:03.793138Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 12.96}
# {"timestamp": "2026-05-10T01:15:05.796316Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.39}
# {"timestamp": "2026-05-10T01:15:06.068456Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 67.94}
# {"timestamp": "2026-05-10T01:15:06.290833Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 35.41}
# {"timestamp": "2026-05-10T01:15:07.287919Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 35.5}
# {"timestamp": "2026-05-10T01:15:18.761891Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 169.49}
# {"timestamp": "2026-05-10T01:15:19.846691Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 370.51}
# {"timestamp": "2026-05-10T01:15:20.537326Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 38.32}
# {"timestamp": "2026-05-10T01:15:20.742899Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 28.3}
# {"timestamp": "2026-05-10T01:15:20.944052Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 26.62}
# {"timestamp": "2026-05-10T01:15:21.048070Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 62.22}
# {"timestamp": "2026-05-10T01:15:21.064188Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-05-10T01:15:21.679088Z", "level": "info", "event": "Top GGUF models: ['unsloth/gemma-4-26B-A4B-it-GGUF', 'unsloth/Qwen3.6-35B-A3B-GGUF', 'unsloth/gemma-4-31B-it-GGUF', 'unsloth/gemma-4-E4B-it-GGUF', 'unsloth/Qwen3.6-27B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/gemma-4-E2B-it-GGUF', 'unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/MiniMax-M2.7-GGUF', 'unsloth/Qwen3-30B-A3B-Instruct-2507-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/Llama-3.3-70B-Instruct-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/Devstral-Small-2505-GGUF', 'unsloth/gemma-3-12b-it-GGUF', 'unsloth/Kimi-K2.6-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/FLUX.2-klein-4B-GGUF', 'unsloth/Kimi-K2.5-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/GLM-4.7-Flash-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-14B-GGUF', 'unsloth/GLM-4.7-GGUF', 'unsloth/FLUX.2-klein-9B-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-1.5B-GGUF']"}
# {"timestamp": "2026-05-10T01:15:21.682085Z", "level": "info", "event": "Top hub models: ['unsloth/gemma-4-E4B-it', 'unsloth/Llama-3.1-8B-Instruct', 'unsloth/gemma-4-31B-it-unsloth-bnb-4bit', 'unsloth/GLM-4.7-Flash', 'unsloth/Mistral-Small-3.2-24B-Instruct-2506-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/gemma-3n-E4B-it', 'unsloth/Qwen3-0.6B', 'unsloth/Qwen3.5-9B', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/gemma-3-1b-it', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/gpt-oss-120b-BF16', 'unsloth/Qwen2.5-7B-Instruct-bnb-4bit', 'unsloth/gemma-4-E4B-it-unsloth-bnb-4bit', 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-0.5B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-Coder-7B-Instruct-bnb-4bit', 'unsloth/gpt-oss-20b-unsloth-bnb-4bit', 'unsloth/Qwen3.6-35B-A3B-UD-MLX-4bit', 'unsloth/Qwen3.5-4B', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/gemma-4-E2B-it-unsloth-bnb-4bit', 'unsloth/Qwen3-0.6B-unsloth-bnb-4bit', 'unsloth/gemma-4-E2B-it', 'unsloth/Qwen2.5-0.5B-Instruct', 'unsloth/DeepSeek-OCR-2', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen2.5-3B-Instruct', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-3B-Instruct-bnb-4bit', 'unsloth/llama-3-8b-Instruct-bnb-4bit', 'unsloth/gemma-4-26B-A4B-it', 'unsloth/Qwen3.5-2B', 'unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct-unsloth-bnb-4bit']"}
# {"timestamp": "2026-05-10T01:15:21.706401Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-05-10T01:15:21.710140Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-05-10T01:15:21.728081Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 675.33}
# {"timestamp": "2026-05-10T01:15:21.730253Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 677.43}
# {"timestamp": "2026-05-10T01:15:21.731401Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 678.48}
# {"timestamp": "2026-05-10T01:15:21.772912Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 35.65}
# {"timestamp": "2026-05-10T01:15:21.976754Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 28.77}
# {"timestamp": "2026-05-10T01:15:25.967520Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 18.5}
# {"timestamp": "2026-05-10T01:15:26.130835Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 157.43}
# {"timestamp": "2026-05-10T01:15:26.132524Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 158.69}
# {"timestamp": "2026-05-10T01:15:26.134941Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 160.96}
# {"timestamp": "2026-05-10T01:15:26.136084Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 162.04}
# {"timestamp": "2026-05-10T01:18:48.145542Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 54.67}
# {"timestamp": "2026-05-10T01:18:48.246706Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 97.17}
# {"timestamp": "2026-05-10T01:18:48.248515Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 98.77}
# {"timestamp": "2026-05-10T01:18:48.278886Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 32.38}
# {"timestamp": "2026-05-10T01:18:48.281343Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 34.75}
# ==

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
